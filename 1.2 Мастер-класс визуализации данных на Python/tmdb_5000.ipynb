# %%
from os import path
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
# plots
from matplotlib import pyplot as plt
import seaborn as sns
from pylab import rcParams

from plotly.offline import init_notebook_mode, iplot
import plotly
import plotly.graph_objs as go
init_notebook_mode(connected=True)

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
# %pylab inline
# %config InlineBackend.figure_format = 'png'
rcParams['figure.figsize'] = (16, 6)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Загрузка данных

# %%
# !ls
# Out:
# tmdb_5000.ipynb       tmdb_5000_credits.csv tmdb_5000_movies.csv

# %%
credits = pd.read_csv('tmdb_5000_credits.csv')
movies = pd.read_csv('tmdb_5000_movies.csv')

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
# pd.DatetimeIndex(pd.to_datetime(movies['release_date'])).year.astype(int)
movies.loc[:, 'year'] = pd.to_datetime(movies['release_date'].fillna(0)).dt.year.values.astype(int)
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# ## Количество фильмов в год

# %%
p = sns.factorplot(x="year", data=movies, aspect=3.5, kind="count", palette="Greens_d");
p.set_xticklabels(rotation=70, fontsize=10)

# %% [markdown]
# ## Топ 10 фильмов по количеству оценок

# %%
sns.barplot(x="vote_count", y='title', data=movies.sort_values('vote_count', ascending=False).iloc[:10], palette=sns.cubehelix_palette(10))

# %% [markdown]
# ## Корреляция между популярностью и доходом
# Посмотрим, существует ли корреляция дохода с популярностью

# %%
iplot([go.Scatter(
    x = movies.sort_values('popularity')['popularity'],
    y = movies.sort_values('popularity')['revenue'],
    mode = 'markers'
)], filename='basic-scatter')
# Out:
# <div id="351207ce-4ede-4e1a-98f6-d9b927e16fcf" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("351207ce-4ede-4e1a-98f6-d9b927e16fcf", [{"mode": "markers", "x": [0.0, 0.00037200000000000004, 0.001117, 0.001186, 0.001389, 0.001586, 0.002386, 0.002388, 0.0031420000000000003, 0.0033520000000000004, 0.003582, 0.004922, 0.004998, 0.005256, 0.005883, 0.006069, 0.006323, 0.006943, 0.007254000000000001, 0.00734, 0.008263, 0.008453, 0.010607, 0.010909, 0.011696999999999999, 0.012941999999999999, 0.014406, 0.015189, 0.015295, 0.015597, 0.015697, 0.018087, 0.018716, 0.019984000000000002, 0.020168000000000002, 0.0206, 0.020839, 0.021391999999999998, 0.021419, 0.021678, 0.022173, 0.023436000000000002, 0.023681, 0.024186000000000003, 0.025211, 0.025363999999999998, 0.027801, 0.027811000000000002, 0.028756, 0.0297
# ...

# %% [markdown]
# ... и с количеством оценок

# %%
sns.jointplot(x='vote_count', y='revenue', data=movies, kind='reg', size=10);

# %% [markdown]
# ## Распределение оценок

# %%
import plotly.figure_factory as ff

# %%
iplot(ff.create_distplot([movies['vote_average']], ['ratings'], bin_size=.5), filename='Rating Distplot')
# Out:
# <div id="1bd453e0-44f9-4ab9-b4b3-da7191bb9714" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1bd453e0-44f9-4ab9-b4b3-da7191bb9714", [{"xbins": {"start": 0.0, "end": 10.0, "size": 0.5}, "autobinx": false, "name": "ratings", "legendgroup": "ratings", "type": "histogram", "opacity": 0.7, "x": [7.2, 6.9, 6.3, 7.6, 6.1, 5.9, 7.4, 7.3, 7.4, 5.7, 5.4, 6.1, 7.0, 5.9, 6.5, 6.3, 7.4, 6.4, 6.2, 7.1, 6.5, 6.2, 7.6, 5.8, 6.6, 7.5, 7.1, 5.5, 6.5, 6.9, 6.7, 6.8, 6.4, 6.3, 7.0, 6.0, 5.8, 5.7, 6.5, 6.3, 5.8, 5.1, 7.6, 5.9, 7.3, 6.7, 7.5, 7.4, 5.5, 7.3, 6.2, 6.7, 6.1, 5.7, 6.6, 6.7, 6.6, 7.8, 6.1, 5.6, 6.6, 5.2, 5.5, 6.7, 6.4, 8.2, 7.7, 6.0, 7.4, 7.0, 5.1, 5.2, 5.9, 5.3, 7.6, 5.9, 5.6, 8.0, 6.7, 6.6, 5.8, 7.0, 7.3, 4.8, 5.9, 7.6, 6.0, 6.2, 7.8, 7.1, 6.4, 4.9, 7.5, 5.9, 7.9, 8.1, 8.1, 6.5, 7.0, 6.6, 7.3, 7.1, 6.6, 
# ...

# %% [markdown]
# ## Средняя продолжительность фильма
# Посмотрим, как менялась средняя продолжительность фильма каждый год

# %%
movies.groupby('year')['runtime'].mean().plot(kind='line', rot=45)
